# %% [markdown]
# <a href="https://colab.research.google.com/github/Rapoulas/data_science_ads/blob/master/Redes_Neurais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from yellowbrick.classifier import ConfusionMatrix
from sklearn.neural_network import MLPClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
caminho = "/content/drive/MyDrive/MaterialApoio/"
# Out:
# Mounted at /content/drive

# %%
with open(caminho+"credit.pkl", 'rb') as f:
  X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_teste = pickle.load(f)

# %%
rede_neural_credit = MLPClassifier(max_iter = 1500, verbose=True, tol=0.0000100, solver='adam', activation='relu', hidden_layer_sizes=(30, 30))
rede_neural_credit.fit(X_credit_treinamento, y_credit_treinamento)
# Out:
# Iteration 1, loss = 0.48726814
# Iteration 2, loss = 0.44149726
# Iteration 3, loss = 0.40663078
# Iteration 4, loss = 0.37695252
# Iteration 5, loss = 0.35170483
# Iteration 6, loss = 0.32919158
# Iteration 7, loss = 0.30766680
# Iteration 8, loss = 0.28640105
# Iteration 9, loss = 0.26606146
# Iteration 10, loss = 0.24575546
# Iteration 11, loss = 0.22662080
# Iteration 12, loss = 0.20906964
# Iteration 13, loss = 0.19223063
# Iteration 14, loss = 0.17730629
# Iteration 15, loss = 0.16338745
# Iteration 16, loss = 0.15103901
# Iteration 17, loss = 0.13964290
# Iteration 18, loss = 0.12960785
# Iteration 19, loss = 0.12064451
# Iteration 20, loss = 0.11296864
# Iteration 21, loss = 0.10595930
# Iteration 22, loss = 0.09958282
# Iteration 23, loss = 0.09402212
# Iteration 24, loss = 0.08887707
# Iteration 25, loss = 0.08426072
# Iteration 26, loss = 0.07990150
# Iteration 27, loss = 0.07612155
# Iteration 28, loss = 0.07256102
# Iteration 29, loss = 0.06946457
# ...

# %%
cm = ConfusionMatrix(rede_neural_credit)
cm.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3496630774.py in <cell line: 0>()
#       1 cm = ConfusionMatrix(rede_neural_credit)
# ----> 2 cm.fit()
#
# TypeError: ClassificationScoreVisualizer.fit() missing 1 required positional argument: 'X'

# %%
accuracy_score(y_credit_teste, previsao_credit)
