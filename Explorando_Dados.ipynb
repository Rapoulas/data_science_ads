# %% [markdown]
# <a href="https://colab.research.google.com/github/Rapoulas/data_science_ads/blob/master/Explorando_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dados**
#
# Podem ser:
#
# - Categóricos
# - Númericos
#
# Os Númericos podem ser:
#
# - Discreto (Números Inteiros, Finitos, Faixas de Números)
# - Contínuo (Números Reais)
#
# Os Categóricos podem ser:
#
# - Ordinal (Ordem, Prioridade, Importância)
# - Nominal (Rotulos, Nomes, Sem ordem, IDs de banco de dados)

# %%
import pandas as pd

# %%
dados = {
    "renda": [6.46, 1.50, 0.00, 2.57, 9.90, 6.22],
    "empregos": [1, 1, 0, 1, 2, 3],
    "sexo": ["F", "M", "F", "M", "M", "F"],
    "escolaridade": ["pós-graduação", "fundamental", "médio", "médio", "superior", "médio"]
}

pme = pd.DataFrame(dados)

print(pme.dtypes)

# %%
# Dados estatísticos básico: Medidas e tendênia central.

# Média
# Mediana
# Moda

dados = {
    "jogador": ["Marelo", "Pedro", "Marcelo", "Adriano", "Mauro", "Pedro", "Marcelo"],
    "infracao": ["FALTA VIOLENTA", "RECLAMACAO", "FALTA COMUM", "RECLAMACAO", "FALTA COMUM", "FALTA VIOLENTA", "RECLAMACAO"],
    "punicao": [4, 1, 3, 2, 4, 4, 2]
}

df = pd.DataFrame(dados)

print("Média: ", df["punicao"].mean())
print("Mediana: ", df["punicao"].median())
print("Moda: ", df["punicao"].mode().values)
# Out:
# Média:  2.857142857142857
# Mediana:  3.0
# Moda:  [4]

# %%
dados = {
    "jogador": ["Marelo", "Pedro", "Marcelo", "Adriano", "Mauro", "Pedro", "Marcelo"],
    "infracao": ["FALTA VIOLENTA", "RECLAMACAO", "FALTA COMUM", "RECLAMACAO", "FALTA COMUM", "FALTA VIOLENTA", "RECLAMACAO"],
    "juiz_A": [4, 1, 3, 2, 4, 4, 2],
    "juiz_B": [2, 1, 4, 1, 1, 5, 6]
}

df = pd.DataFrame(dados)

print("Juiz A")
print("Média: ", f"{df['juiz_A'].mean():.3f}")
print("Mediana: ", df["juiz_A"].median())
print("Moda: ", df["juiz_A"].mode().values)
print("Amplitude: ", df["juiz_A"].max() - df["juiz_A"].min())
print("Variância: ", f"{df['juiz_A'].var():.3f}")
print("Desvio Padrão: ", f"{df['juiz_A'].std():.3f}")
print()
print("Juiz B")
print("Média: ", df["juiz_B"].mean())
print("Mediana: ", df["juiz_B"].median())
print("Moda: ", df["juiz_B"].mode().values)
print("Amplitude: ", df["juiz_B"].max() - df["juiz_B"].min())
print("Variância: ", f"{df['juiz_B'].var():.3f}")
print("Desvio Padrão: ", f"{df['juiz_B'].std():.3f}")
# Out:
# Juiz A
# Média:  2.857
# Mediana:  3.0
# Moda:  [4]
# Amplitude:  3
# Variância:  1.476
# Desvio Padrão:  1.215
#
# Juiz B
# Média:  2.857142857142857
# Mediana:  2.0
# Moda:  [1]
# Amplitude:  5
# Variância:  4.476
# Desvio Padrão:  2.116

# %%
ja_amplitude =  round(df['juiz_A'].max() - df['juiz_A'].min(), 3)
ja_variacao = round(df['juiz_A'].var(), 3)
ja_desvio = round(df['juiz_A'].std(), 3)
ja_media = round(df["juiz_A"].mean(), 3)
ja_mediana = round(df["juiz_A"].median(), 3)
ja_moda = df["juiz_A"].mode().values

jb_amplitude =  round(df["juiz_B"].max() - df["juiz_B"].min(), 3)
jb_variacao = round(df['juiz_B'].var(), 3)
jb_desvio = round(df['juiz_B'].std(), 3)
jb_media = round(df["juiz_B"].mean(), 3)
jb_mediana = round(df["juiz_B"].median(), 3)
jb_moda = df["juiz_B"].mode().values

print ("Valores         | Juiz A     |     Juiz B      ")
print ("-------------------------------------------------")
print ("Amplitude       |", ja_amplitude, "         |    ", jb_amplitude)
print ("Variância       |", ja_variacao, "     |    ", jb_variacao)
print ("Desvio Padrão   |", ja_desvio, "     |    ", jb_desvio)
print ("Média           |", ja_media, "     |    ", jb_media)
print ("Mediana         |", ja_mediana, "       |    ", jb_mediana)
print ("Moda            |", ja_moda[0], "         |    ", jb_moda[0])
# Out:
# Valores         | Juiz A     |     Juiz B
# -------------------------------------------------
# Amplitude       | 3          |     5
# Variância       | 1.476      |     4.476
# Desvio Padrão   | 1.215      |     2.116
# Média           | 2.857      |     2.857
# Mediana         | 3.0        |     2.0
# Moda            | 4          |     1

# %%
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "homens": [4, 2, 7 ,3, 1, 4, 2, 4, 8, 1],
    "mulheres": [5, 4, 6, 5, 4, 2, 6, 6, 4, 3]
})

boxplot = df.boxplot(column=["homens", "mulheres"], showmeans=True)

plt.show()

# %%
notas = pd.DataFrame({
    "A1": [9.8, 7.2, 8.0],
    "A2": [5.3, 4.0, 3.5],
    "A3": [5.5, 8.1, 7.2],
    "A4": [7.0, 7.5, 6.5],
}, index=["P1", "P2", "P3"])

print("Notas Finais ")
print("-----------------------------")
print(notas)
print()
print("Média Aritmética: ", notas.mean(axis=1))
print("Média de cada aluno ")
print()
print(notas.mean())
print()

print("Maior nota de cada aluno")
print("-----------------------------")
print(notas.max())
print()

print("Menor nota de cada aluno")
print("-----------------------------")
print(notas.min())
print()

print("Maior nota da turma")
print("-----------------------------")
print(notas.max().max)

print("Média de cada prova")
print("-----------------------------")
print(notas.mean(axis=1))

print("Maior nota de cada prova")
print("-----------------------------")
print(notas.max(axis=1))

print("Menor nota de cada prova")
print("-----------------------------")
print(notas.min(axis=1))
# Out:
# Notas Finais
# -----------------------------
#      A1   A2   A3   A4
# P1  9.8  5.3  5.5  7.0
# P2  7.2  4.0  8.1  7.5
# P3  8.0  3.5  7.2  6.5
#
# Média Aritmética:  P1    6.9
# P2    6.7
# P3    6.3
# dtype: float64
# Média de cada aluno
#
# A1    8.333333
# A2    4.266667
# A3    6.933333
# A4    7.000000
# dtype: float64
#
# Maior nota de cada aluno
# -----------------------------
# A1    9.8
# A2    5.3
# A3    8.1
# A4    7.5
# dtype: float64
#
# Menor nota de cada aluno
# -----------------------------
# A1    7.2
# A2    3.5
# A3    5.5
# A4    6.5
# dtype: float64
#
# Maior nota da turma
# -----------------------------
# <bound method Series.max of A1    9.8
# A2    5.3
# A3    8.1
# A4    7.5
# dtype: float64>
# Média de cada prova
# -----------------------------
# P1    6.9
# P2    6.7
# P3    6.3
# dtype: float64
# Maior nota de cada prova
# -----------------------------
# P1    9.8
# P2    8.1
# P3    8.0
# dtype: float64
# Menor nota de cada prova
# -----------------------------
# P1    5.3
# P2    4.0
# P3    3.5
# dtype: float64

# %%
dados = {
    "nadador": ["Simonas Bills", "Benajamin Pround", "Antony Ervin", "Florent Manaudou", "Andrly Hovorov", "Nathan Adrian", "Bruno Fratus", "Brad Tandy"],
    "nacionalidade": ["Lituãnia", "Grã-Bretanha", "Estados Unidos", "França", "Ucrânia", "Estados Unidos", "Brasil", "Africa do Sul"],
    "tempo": [22.08, 21.68, 21.40, 21.41, 21.74, 21.49, 21.79, 21.79]
}

raias = list(range(1,9))
prova50m = pd.DataFrame(dados, index=raias)

prova50m.index.name = "raia"

prova50m = prova50m.sort_values(by="tempo")

print(prova50m)

resultado_por_raia = prova50m['tempo'].rank(method='min')
print(resultado_por_raia)
# Out:
#                nadador   nacionalidade  tempo
# raia
# 3         Antony Ervin  Estados Unidos  21.40
# 4     Florent Manaudou          França  21.41
# 6        Nathan Adrian  Estados Unidos  21.49
# 2     Benajamin Pround    Grã-Bretanha  21.68
# 5       Andrly Hovorov         Ucrânia  21.74
# 7         Bruno Fratus          Brasil  21.79
# 8           Brad Tandy   Africa do Sul  21.79
# 1        Simonas Bills        Lituãnia  22.08
# raia
# 3    1.0
# 4    2.0
# 6    3.0
# 2    4.0
# 5    5.0
# 7    6.0
# 8    6.0
# 1    8.0
# Name: tempo, dtype: float64

# %%
dados = { "sexo": ["F", "M", "F", "F", "F", "M"],
          "bairro": ["Belverde",
                     "Belverde",
                     "Savassi",
                     "Anchieta",
                     None,
                     "Savassi"],
          "valor": [150.00,
                    35.00,
                    80.00,
                    250.00,
                    9.90,
                    25.00],
          "cartao": ["Master",
                     "Visa",
                     "Visa",
                     "Amex",
                     "Elo",
                     "Master"]}
id_clientes = [1, 2, 3, 4, 5, 6]

vendas = pd.DataFrame(dados, index=id_clientes)

# %%
print("Dominio dos atributos categóricos")
print("---------------------------------")
print("sexo: ", vendas['sexo'].unique())
print("bairro: ", vendas['bairro'].unique())
print("cartao: ", vendas['cartao'].unique())
# Out:
# Dominio dos atributos categóricos
# ---------------------------------
# sexo:  ['F' 'M']
# bairro:  ['Belverde' 'Savassi' 'Anchieta' None]
# valor:  [150.   35.   80.  250.    9.9  25. ]
# cartao:  ['Master' 'Visa' 'Amex' 'Elo']

# %%
print("Tabela de frequência")
print("---------------------")
print(vendas['sexo'].value_counts())
print("---------------------------")
print(vendas['bairro'].value_counts())
print("-----------------------------")
print(vendas['cartao'].value_counts())
# Out:
# Tabela de frequência
# ---------------------
# sexo
# F    4
# M    2
# Name: count, dtype: int64
# ---------------------------
# bairro
# Belverde    2
# Savassi     2
# Anchieta    1
# Name: count, dtype: int64
# -----------------------------
# cartao
# Master    2
# Visa      2
# Amex      1
# Elo       1
# Name: count, dtype: int64

# %%
grupo_valor_bairro = vendas['valor'].groupby(vendas['bairro'])

print(grupo_valor_bairro.count())
print("-------------------------")
print(grupo_valor_bairro.sum())
print("-------------------------")
print(grupo_valor_bairro.mean())
# Out:
# bairro
# Anchieta    1
# Belverde    2
# Savassi     2
# Name: valor, dtype: int64
# -------------------------
# bairro
# Anchieta    250.0
# Belverde    185.0
# Savassi     105.0
# Name: valor, dtype: float64
# -------------------------
# bairro
# Anchieta    250.0
# Belverde     92.5
# Savassi      52.5
# Name: valor, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({"x": list(range(1,11))})
df["y"] = (df.x * 2) + 3
lines = df.plot.line(x="x", y="y", legend=False)

plt.show(lines)

# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = {"óleo de soja": [71.25, 66.93, 67.91, 67.66],
         "melancia": [10.52, 15.68, 14.95, 36.23],
         "frango congelado": [47.17, 23.68, 38.36, 17.08]}

df = pd.DataFrame(dados, index=[3, 6, 9, 12])

lines = df.plot(kind="line",
                style=[".-", "+-", "*-"],
                ylim=(0, 100),
                xlim=(3, 12))

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({"mulheres": [40, 10, 30],
                  "homens": [30, 15, 20]},
                  index=["teatro", "escultura", "pintura"])
barras = df.plot(kind="bar", legend=False, color=["yellow", "blue"])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "tempo": [4, 5, 1, 7, 7, 8, 6, 6, 5,
              2, 5, 8, 7, 1, 6, 3, 4, 8,
              5, 7, 4, 6, 3, 6, 2, 6, 8]
})

hist = df.plot(kind="hist", bins=5)
plt.show()

# %%
boxplot = df.boxplot(column=["tempo"], showmeans=True)

plt.show()

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

flags = pd.read_csv("/content/drive/MyDrive/MaterialApoio/flags.csv")
# Out:
# Mounted at /content/drive

# %%
flags
# Out:
#                name  landmass  zone  area  population  language  religion  \
# 0       Afghanistan         5     1   648          16        10         2
# 1           Albania         3     1    29           3         6         6
# 2           Algeria         4     1  2388          20         8         2
# 3    American-Samoa         6     3     0           0         1         1
# 4           Andorra         3     1     0           0         6         0
# ..              ...       ...   ...   ...         ...       ...       ...
# 189   Western-Samoa         6     3     3           0         1         1
# 190      Yugoslavia         3     1   256          22         6         6
# 191           Zaire         4     2   905          28        10         5
# 192          Zambia         4     2   753           6        10         5
# 193        Zimbabwe         4     2   391           8        10         5
#
#      bars  stripes  colours  ...  saltires  quarters  sunstars  crescent  \
# 0       0        3        5  ...         0         0         1         0
# 1       0        0        3  ...         0         0         1         0
# 2       2        0        3  ...         0         0         1         1
# 3       0        0        5  ...         0         0         0         0
# 4       3        0        3  ...         0         0         0         0
# ..    ...      ...      ...  ...       ...       ...       ...       ...
# 189     0        0        3  ...         0         1         5         0
# 190     0        3        4  ...         0         0         1         0
# 191     0        0        4  ...         0         0         0         0
# 192     3        0        4  ...         0         0         0         0
# 193     0        7        5  ...         0         0         1         0
#
#      triangle  icon  animate text  topleft  botright
# 0           0     1        0    0    black     green
# 1           0     0        1    0      red       red
# 2           0     0        0    0    green     white
# 3           1     1        1    0     blue       red
# 4           0     0        0    0     blue       red
# ..        ...   ...      ...  ...      ...       ...
# 189         0     0        0    0     blue       red
# 190         0     0        0    0     blue       red
# 191         0     1        1    0    green     green
# 192         0     0        1    0    green     brown
# 193         1     1        1    0    green     green
#
# [194 rows x 30 columns]

# %%
i = 0
for c in flags.columns:
    i += 1
    att = flags[c]
    att_dtype = att.dtype
    att_tam_dominio = att.unique().size
    att_tem_nulo = any(att.isnull())
    if(att_tam_dominio < 8):
      print(f"({str(i)}) atributo: {c} \n dtype: {att_dtype} \n nulos: {att_tem_nulo} \n dominio: {att.unique}")
# Out:
# (2) atributo: landmass
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      5
# 1      3
# 2      4
# 3      6
# 4      3
#       ..
# 189    6
# 190    3
# 191    4
# 192    4
# 193    4
# Name: landmass, Length: 194, dtype: int64>
# (3) atributo: zone
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      1
# 1      1
# 2      1
# 3      3
# 4      1
#       ..
# 189    3
# 190    1
# 191    2
# 192    2
# 193    2
# Name: zone, Length: 194, dtype: int64>
# (8) atributo: bars
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      2
# 3      0
# 4      3
#       ..
# 189    0
# 190    0
# 191    0
# 192    3
# 193    0
# Name: bars, Length: 194, dtype: int64>
# (11) atributo: red
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 189    1
# 190    1
# 191    1
# 192    1
# 193    1
# Name: red, Length: 194, dtype: int64>
# (12) atributo: green
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 189    0
# 190    0
# 191    1
# 192    1
# 193    1
# Name: green, Length: 194, dtype: int64>
# (13) atributo: blue
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 189    1
# 190    1
# 191    0
# 192    0
# 193    0
# Name: blue, Length: 194, dtype: int64>
# (14) atributo: gold
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      1
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 189    0
# 190    1
# 191    1
# 192    0
# 193    1
# Name: gold, Length: 194, dtype: int64>
# (15) atributo: white
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 189    1
# 190    1
# 191    0
# 192    0
# 193    1
# Name: white, Length: 194, dtype: int64>
# (16) atributo: black
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 189    0
# 190    0
# 191    0
# 192    1
# 193    1
# Name: black, Length: 194, dtype: int64>
# (17) atributo: orange
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 189    0
# 190    0
# 191    1
# 192    1
# 193    0
# Name: orange, Length: 194, dtype: int64>
# (19) atributo: circles
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 189    0
# 190    0
# 191    1
# 192    0
# 193    0
# Name: circles, Length: 194, dtype: int64>
# (20) atributo: crosses
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 189    0
# 190    0
# 191    0
# 192    0
# 193    0
# Name: crosses, Length: 194, dtype: int64>
# (21) atributo: saltires
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 189    0
# 190    0
# 191    0
# 192    0
# 193    0
# Name: saltires, Length: 194, dtype: int64>
# (22) atributo: quarters
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 189    1
# 190    0
# 191    0
# 192    0
# 193    0
# Name: quarters, Length: 194, dtype: int64>
# (24) atributo: crescent
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 189    0
# 190    0
# 191    0
# 192    0
# 193    0
# Name: crescent, Length: 194, dtype: int64>
# (25) atributo: triangle
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 189    0
# 190    0
# 191    0
# 192    0
# 193    1
# Name: triangle, Length: 194, dtype: int64>
# (26) atributo: icon
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 189    0
# 190    0
# 191    1
# 192    0
# 193    1
# Name: icon, Length: 194, dtype: int64>
# (27) atributo: animate
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 189    0
# 190    0
# 191    1
# 192    1
# 193    1
# Name: animate, Length: 194, dtype: int64>
# (28) atributo: text
#  dtype: int64
#  nulos: False 	 dominio: <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 189    0
# 190    0
# 191    0
# 192    0
# 193    0
# Name: text, Length: 194, dtype: int64>
# (29) atributo: topleft
#  dtype: object
#  nulos: False 	 dominio: <bound method Series.unique of 0      black
# 1        red
# 2      green
# 3       blue
# 4       blue
#        ...
# 189     blue
# 190     blue
# 191    green
# 192    green
# 193    green
# Name: topleft, Length: 194, dtype: object>
